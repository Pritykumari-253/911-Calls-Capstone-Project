# %%
# Install TensorFlow
# !pip install -q tensorflow-gpu==2.0.0-beta1

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# 2.6.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D
from tensorflow.keras.models import Model

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print("x_train.shape:", x_train.shape)
print("y_train.shape", y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step
# x_train.shape: (50000, 32, 32, 3)
# y_train.shape (50000,)

# %%
# number of classes
K = len(set(y_train))
print("number of classes:", K)
# Out:
# number of classes: 10

# %%
# Build the model using the functional API
i = Input(shape=x_train[0].shape)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(i)
x = Dropout(0.5)(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Dropout(0.5)(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Dropout(0.5)(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %%
# Compile and fit
# Note: make sure you are using the GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 14s 8ms/step - loss: 1.2797 - accuracy: 0.5511 - val_loss: 1.1607 - val_accuracy: 0.5950
# Epoch 2/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2728 - accuracy: 0.5477 - val_loss: 1.1357 - val_accuracy: 0.6039
# Epoch 3/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2769 - accuracy: 0.5478 - val_loss: 1.1730 - val_accuracy: 0.5795
# Epoch 4/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2732 - accuracy: 0.5501 - val_loss: 1.1698 - val_accuracy: 0.5977
# Epoch 5/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2780 - accuracy: 0.5470 - val_loss: 1.1713 - val_accuracy: 0.5979
# Epoch 6/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2670 - accuracy: 0.5483 - val_loss: 1.2506 - val_accuracy: 0.5589
# Epoch 7/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2691 - accuracy: 0.5481 - val_loss: 1.1714 - val_accuracy: 0.6089
# Epoch 8/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2555 - accuracy: 0.5540 - val_loss: 1.1450 - val_accuracy: 0.6204
# Epoch 9/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2622 - accuracy: 0.5511 - val_loss: 1.1623 - val_accuracy: 0.6082
# Epoch 10/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2663 - accuracy: 0.5521 - val_loss: 1.1438 - val_accuracy: 0.6040
# Epoch 11/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2672 - accuracy: 0.5502 - val_loss: 1.1104 - val_accuracy: 0.6211
# Epoch 12/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2608 - accuracy: 0.5507 - val_loss: 1.1511 - val_accuracy: 0.6186
# Epoch 13/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2494 - accuracy: 0.5572 - val_loss: 1.1469 - val_accuracy: 0.5908
# Epoch 14/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2568 - accuracy: 0.5560 - val_loss: 1.1272 - val_accuracy: 0.6147
# Epoch 15/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2608 - accuracy: 0.5538 - val_loss: 1.0872 - val_accuracy: 0.6259
# Epoch 16/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2644 - accuracy: 0.5506 - val_loss: 1.1184 - val_accuracy: 0.6166
# Epoch 17/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2499 - accuracy: 0.5589 - val_loss: 1.2996 - val_accuracy: 0.5472
# Epoch 18/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2551 - accuracy: 0.5572 - val_loss: 1.1238 - val_accuracy: 0.6146
# Epoch 19/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2516 - accuracy: 0.5600 - val_loss: 1.1359 - val_accuracy: 0.6040
# Epoch 20/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2598 - accuracy: 0.5525 - val_loss: 1.0995 - val_accuracy: 0.6258
# Epoch 21/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2513 - accuracy: 0.5598 - val_loss: 1.1238 - val_accuracy: 0.6152
# Epoch 22/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2552 - accuracy: 0.5513 - val_loss: 1.1399 - val_accuracy: 0.6142
# Epoch 23/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2454 - accuracy: 0.5562 - val_loss: 1.1041 - val_accuracy: 0.6212
# Epoch 24/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2504 - accuracy: 0.5558 - val_loss: 1.0977 - val_accuracy: 0.6316
# Epoch 25/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2486 - accuracy: 0.5540 - val_loss: 1.1153 - val_accuracy: 0.6077
# Epoch 26/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.2631 - accuracy: 0.5528 - val_loss: 1.1595 - val_accuracy: 0.6043
# Epoch 27/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2561 - accuracy: 0.5553 - val_loss: 1.0981 - val_accuracy: 0.6208
# Epoch 28/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2489 - accuracy: 0.5598 - val_loss: 1.1013 - val_accuracy: 0.6318
# Epoch 29/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2510 - accuracy: 0.5579 - val_loss: 1.1114 - val_accuracy: 0.6147
# Epoch 30/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2553 - accuracy: 0.5538 - val_loss: 1.1019 - val_accuracy: 0.6265
# Epoch 31/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2520 - accuracy: 0.5538 - val_loss: 1.0901 - val_accuracy: 0.6363
# Epoch 32/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2480 - accuracy: 0.5597 - val_loss: 1.1004 - val_accuracy: 0.6316
# Epoch 33/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2475 - accuracy: 0.5572 - val_loss: 1.0703 - val_accuracy: 0.6416
# Epoch 34/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2481 - accuracy: 0.5579 - val_loss: 1.0962 - val_accuracy: 0.6210
# Epoch 35/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2490 - accuracy: 0.5589 - val_loss: 1.1656 - val_accuracy: 0.5966
# Epoch 36/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2572 - accuracy: 0.5554 - val_loss: 1.0696 - val_accuracy: 0.6368
# Epoch 37/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2479 - accuracy: 0.5556 - val_loss: 1.1213 - val_accuracy: 0.6117
# Epoch 38/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2529 - accuracy: 0.5567 - val_loss: 1.1340 - val_accuracy: 0.6109
# Epoch 39/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2641 - accuracy: 0.5527 - val_loss: 1.0860 - val_accuracy: 0.6389
# Epoch 40/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2536 - accuracy: 0.5555 - val_loss: 1.1274 - val_accuracy: 0.6042
# Epoch 41/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2462 - accuracy: 0.5601 - val_loss: 1.1087 - val_accuracy: 0.6160
# Epoch 42/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2508 - accuracy: 0.5613 - val_loss: 1.0976 - val_accuracy: 0.6169
# Epoch 43/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2384 - accuracy: 0.5637 - val_loss: 1.0877 - val_accuracy: 0.6208
# Epoch 44/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2418 - accuracy: 0.5575 - val_loss: 1.0933 - val_accuracy: 0.6353
# Epoch 45/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2502 - accuracy: 0.5567 - val_loss: 1.0930 - val_accuracy: 0.6266
# Epoch 46/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2556 - accuracy: 0.5575 - val_loss: 1.0931 - val_accuracy: 0.6271
# Epoch 47/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2304 - accuracy: 0.5639 - val_loss: 1.1170 - val_accuracy: 0.6155
# Epoch 48/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2460 - accuracy: 0.5596 - val_loss: 1.1274 - val_accuracy: 0.6045
# Epoch 49/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2600 - accuracy: 0.5547 - val_loss: 1.0857 - val_accuracy: 0.6298
# Epoch 50/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2448 - accuracy: 0.5581 - val_loss: 1.0658 - val_accuracy: 0.6433
# Epoch 51/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2408 - accuracy: 0.5601 - val_loss: 1.1057 - val_accuracy: 0.6315
# Epoch 52/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2347 - accuracy: 0.5621 - val_loss: 1.0704 - val_accuracy: 0.6484
# Epoch 53/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2417 - accuracy: 0.5643 - val_loss: 1.1257 - val_accuracy: 0.6062
# Epoch 54/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2396 - accuracy: 0.5576 - val_loss: 1.1046 - val_accuracy: 0.6194
# Epoch 55/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2413 - accuracy: 0.5622 - val_loss: 1.1639 - val_accuracy: 0.6003
# Epoch 56/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2428 - accuracy: 0.5576 - val_loss: 1.1366 - val_accuracy: 0.6127
# Epoch 57/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2539 - accuracy: 0.5581 - val_loss: 1.1480 - val_accuracy: 0.6024
# Epoch 58/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2401 - accuracy: 0.5643 - val_loss: 1.1101 - val_accuracy: 0.6234
# Epoch 59/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2312 - accuracy: 0.5623 - val_loss: 1.1307 - val_accuracy: 0.6180
# Epoch 60/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2431 - accuracy: 0.5618 - val_loss: 1.0746 - val_accuracy: 0.6307
# Epoch 61/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2572 - accuracy: 0.5550 - val_loss: 1.0970 - val_accuracy: 0.6238
# Epoch 62/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2565 - accuracy: 0.5556 - val_loss: 1.0953 - val_accuracy: 0.6207
# Epoch 63/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2360 - accuracy: 0.5643 - val_loss: 1.0780 - val_accuracy: 0.6363
# Epoch 64/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2487 - accuracy: 0.5550 - val_loss: 1.0749 - val_accuracy: 0.6284
# Epoch 65/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2465 - accuracy: 0.5621 - val_loss: 1.0639 - val_accuracy: 0.6500
# Epoch 66/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2324 - accuracy: 0.5657 - val_loss: 1.0663 - val_accuracy: 0.6441
# Epoch 67/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2332 - accuracy: 0.5648 - val_loss: 1.0839 - val_accuracy: 0.6318
# Epoch 68/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2425 - accuracy: 0.5607 - val_loss: 1.0849 - val_accuracy: 0.6324
# Epoch 69/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2295 - accuracy: 0.5711 - val_loss: 1.0915 - val_accuracy: 0.6243
# Epoch 70/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2474 - accuracy: 0.5615 - val_loss: 1.0511 - val_accuracy: 0.6494
# Epoch 71/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2257 - accuracy: 0.5683 - val_loss: 1.1324 - val_accuracy: 0.6113
# Epoch 72/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2285 - accuracy: 0.5662 - val_loss: 1.0819 - val_accuracy: 0.6340
# Epoch 73/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2474 - accuracy: 0.5603 - val_loss: 1.0626 - val_accuracy: 0.6458
# Epoch 74/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2405 - accuracy: 0.5683 - val_loss: 1.0623 - val_accuracy: 0.6338
# Epoch 75/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2373 - accuracy: 0.5691 - val_loss: 1.0724 - val_accuracy: 0.6376
# Epoch 76/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2363 - accuracy: 0.5649 - val_loss: 1.1356 - val_accuracy: 0.6063
# Epoch 77/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2317 - accuracy: 0.5672 - val_loss: 1.0973 - val_accuracy: 0.6145
# Epoch 78/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2535 - accuracy: 0.5583 - val_loss: 1.1153 - val_accuracy: 0.6107
# Epoch 79/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2346 - accuracy: 0.5664 - val_loss: 1.0851 - val_accuracy: 0.6228
# Epoch 80/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2437 - accuracy: 0.5615 - val_loss: 1.0793 - val_accuracy: 0.6366
# Epoch 81/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2353 - accuracy: 0.5585 - val_loss: 1.0523 - val_accuracy: 0.6357
# Epoch 82/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2408 - accuracy: 0.5647 - val_loss: 1.0556 - val_accuracy: 0.6456
# Epoch 83/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2283 - accuracy: 0.5661 - val_loss: 1.0535 - val_accuracy: 0.6413
# Epoch 84/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2279 - accuracy: 0.5664 - val_loss: 1.0775 - val_accuracy: 0.6347
# Epoch 85/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2373 - accuracy: 0.5708 - val_loss: 1.0940 - val_accuracy: 0.6224
# Epoch 86/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2331 - accuracy: 0.5676 - val_loss: 1.0658 - val_accuracy: 0.6364
# Epoch 87/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2422 - accuracy: 0.5576 - val_loss: 1.0651 - val_accuracy: 0.6305
# Epoch 88/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2312 - accuracy: 0.5677 - val_loss: 1.0594 - val_accuracy: 0.6407
# Epoch 89/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2357 - accuracy: 0.5635 - val_loss: 1.0907 - val_accuracy: 0.6214
# Epoch 90/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2308 - accuracy: 0.5679 - val_loss: 1.0539 - val_accuracy: 0.6413
# Epoch 91/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2378 - accuracy: 0.5625 - val_loss: 1.0698 - val_accuracy: 0.6296
# Epoch 92/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2347 - accuracy: 0.5643 - val_loss: 1.0777 - val_accuracy: 0.6296
# Epoch 93/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2349 - accuracy: 0.5641 - val_loss: 1.0851 - val_accuracy: 0.6342
# Epoch 94/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2429 - accuracy: 0.5612 - val_loss: 1.0536 - val_accuracy: 0.6338
# Epoch 95/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2429 - accuracy: 0.5624 - val_loss: 1.1159 - val_accuracy: 0.6157
# Epoch 96/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2445 - accuracy: 0.5634 - val_loss: 1.0795 - val_accuracy: 0.6312
# Epoch 97/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2235 - accuracy: 0.5678 - val_loss: 1.0774 - val_accuracy: 0.6417
# Epoch 98/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2346 - accuracy: 0.5644 - val_loss: 1.1267 - val_accuracy: 0.6129
# Epoch 99/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2520 - accuracy: 0.5559 - val_loss: 1.0630 - val_accuracy: 0.6415
# Epoch 100/100
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.2294 - accuracy: 0.5670 - val_loss: 1.0343 - val_accuracy: 0.6478

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()


p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix, without normalization
# [[743  13  31  13  28  11  11  18  87  45]
#  [ 10 797   3  12   5   9   7   4  35 118]
#  [ 69  10 558  62 114  79  56  25  20   7]
#  [ 20   9  55 466  73 259  46  50  13   9]
#  [ 15   0  45  54 735  45  29  63   9   5]
#  [ 12   4  37 139  54 684  13  47   4   6]
#  [  6   6  29  87  58  57 738   8   8   3]
#  [ 13   1  19  33  82  60   2 777   4   9]
#  [ 44  25  14  11  13  14   5   6 842  26]
#  [ 34  59   7  16   9  12   8  23  36 796]]

# %%
# label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]));

# %%
![]('ship.jpg')
